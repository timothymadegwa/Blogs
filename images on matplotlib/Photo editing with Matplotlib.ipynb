# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg # optional

# %%
img=mpimg.imread('IMG_0219 copy.jpg') #optional
img=plt.imread('IMG_0219 copy.jpg')

# %%
#checking the type of the image
type(img)
# Out:
# numpy.ndarray

# %%
#checking the shape of the image
img.shape
# Out:
# (1926, 2694, 3)

# %%
img.ndim
# Out:
# 3

# %%
img[:5,:5]
# Out:
# array([[[ 88, 162, 191],
#         [ 89, 163, 192],
#         [ 87, 161, 190],
#         [ 83, 157, 186],
#         [ 86, 160, 189]],
#
#        [[ 89, 163, 192],
#         [ 84, 158, 187],
#         [ 82, 156, 185],
#         [ 85, 159, 188],
#         [ 87, 161, 190]],
#
#        [[ 91, 165, 194],
#         [ 86, 160, 189],
#         [ 84, 158, 187],
#         [ 88, 162, 191],
#         [ 90, 164, 193]],
#
#        [[ 86, 160, 189],
#         [ 89, 163, 192],
#         [ 89, 163, 192],
#         [ 87, 161, 190],
#         [ 88, 162, 191]],
#
#        [[ 81, 155, 184],
#         [ 84, 158, 187],
#         [ 85, 159, 188],
#         [ 84, 158, 187],
#         [ 87, 161, 190]]], dtype=uint8)

# %%
plt.imshow(img)
plt.axis('off')
plt.show()

# %%
plt.imshow(img[:,:,0], cmap='hot')
plt.axis('off')
plt.show()

# %%
plt.imshow(img[:,:,1],cmap='bone')
plt.axis('off')
plt.show()

# %%
plt.imshow(img[:,:,1],cmap='summer')
plt.axis('off')
plt.show()

# %%
plt.imshow(img[:,:,1],cmap='rainbow')
plt.axis('off')
plt.show()

# %%
plt.imshow(img[:,:,2],cmap='hot1')
plt.axis('off')
plt.show()

# %%
img_collapsed= img.mean(axis=2)
print(img_collapsed.shape)
plt.imshow(img_collapsed)
plt.axis('off')
plt.show()
# Out:
# (1926, 2694)

# %%
plt.imshow(img_collapsed, cmap='hot')
plt.axis('off')
plt.show()

# %%
plt.imshow(img_collapsed, cmap='gray')
plt.axis('off')
plt.show()

# %%
plt.imshow(img_collapsed, aspect=0.5)

# %%
plt.imshow(img_collapsed, cmap='gray', extent=(500,2000,0,1500))

# %%
img_collapsed.shape
# Out:
# (1926, 2694)

# %%
compressed = img_collapsed[::3, ::3]

# %%
compressed.shape
# Out:
# (642, 898)

# %%
plt.imshow(compressed,cmap='gray')
plt.axis('off')
plt.savefig('edited')

# %%
plt.imshow
